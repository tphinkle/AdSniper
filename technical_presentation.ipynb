# %% [markdown]
# # AdSniper: Find clusters of similar users based on their app usage for more specific ad targeting.

# %% [markdown]
# ## App usage was categorized by
# 1. Times spent on specific apps
# 2. Total time that users spent on individual app categories
#     - e.g. 'Communication', 'Lifestyle', 'Media & Video', ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Front end runtime for a 'social networker' user : On the graph below we can see from top to bottom the usage of different apps (facebook, instagram and twitter) throughout the day.
#
# ![plot](https://github.com/tphinkle/AdSniper/blob/master/data/plots/1801565_twitter_.png)

# %% [markdown]
# ### Front end runtime for a 'gamer' user : On the graph below we can see a user that uses facebook (during the day) and games (candy crush) later at night
#
# ![plot](./data/plots/2378698_facebook_candy_2.png)

# %% [markdown]
# ### What other apps do users of specific categories like/dislike using?
# ![Correlation matrix](./data/plots/corr_heatmap.png)

# %% [markdown]
# ### Example: expanded view of column 26 in above plot: Sports game users' behavior

# %%
from app_use_groups import *
# %matplotlib inline

# %%
best_relations(26)
plot_category(26,label_threshold=0.15)
# Out:
# People who often use Sports Games apps...
#
# ... really like Action apps.
#
# ... like Communication, Media & Video, Education, and Trivia apps.
#
# ... kind of like Lifestyle, Photography, News & Magazines, Social, Sports, Personalization, Board, Music, and Role Playing apps.
#
# ... neither like nor dislike Music & Audio, Weather, Productivity, Business, Books & Reference, Shopping, Tools, Travel & Local, Libraries & Demo, Arcade & Action, Brain & Puzzle, Cards & Casino, Casual, Racing, Entertainment, Transportation, Live Wallpaper, Widgets, Adventure, Card, Casino, Educational, Family, Puzzle, Simulation, Sports, Strategy, Word, and Arcade apps.
#
# ... kind of dislike Finance, Health & Fitness, and Medical apps.
#
# ... really dislike Comics apps.

# %% [markdown]
# ### The clusters are represented by 49-dimensional vectors that point to the cluster centroid in the app category feature space
# ![Cluster centroids](./data/plots/cluster_centroid_vectors.png)

# %% [markdown]
# ### Cluster centroids and cluster-assigned data projected onto two axes
# ![clustering 2](./data/plots/kmeans/4_1.png)
